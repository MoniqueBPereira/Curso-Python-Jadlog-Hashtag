# %% [markdown]
# Importando Bibliotecas

# %%
import os
import smtplib 
import shutil 
import pyautogui
import pywhatkit as kit
import win32com.client as win32
from time import sleep
from email.message import EmailMessage
from datetime import datetime

# %% [markdown]
# Organizando aquivos

# %%
arquivo_excel = 'contas_processadas.xlsx'
pasta_base = 'base'

# %% [markdown]
# Verificando se o arquivo existe

# %%
if not os.path.exists(arquivo_excel):
    raise FileNotFoundError("Arquivo não encontrado, verifique se o download está concluído.")
# raise modifica a mensagem do código de erro
print("Arquivo encontrado!")
# Out:
# Arquivo encontrado!

# %% [markdown]
# Criando a pasta base dentro da pasta Aula 04

# %%
if not  os.path.exists(pasta_base):
    os.makedirs(pasta_base)
    print("Pasta criada com sucesso!")

else:
    print("Pasta base já existe!")
# Out:
# Pasta criada com sucesso!

# %% [markdown]
# Movendo arquivo para dentro da pasta Base

# %%
destino = os.path.join(pasta_base, os.path.basename(arquivo_excel))

if not os.path.exists(destino):
    shutil.move(arquivo_excel, destino)
    print('Arquivo movido com sucesso!')

else:
    print('Arquivo já existe na pasta Base')
# Out:
# Arquivo já existe na pasta Base

# %% [markdown]
# Criando corpo do E-mail

# %%
hoje = datetime.now().strftime("%d.%m.%Y | Hora: %H:%M")

corpo_email = f""" 
Prezados, 

Segue em anexo, o relatório de contas processadas do mês de Janeiro.
Data de processamento: {hoje}

Fico a disposição em caso de dúvidas.
"""

# %% [markdown]
# Configurando Outlook

# %%
outlook = win32.Dispatch('Outlook.Application')

email = outlook.CreateItem(0)

email.To = 'monique.batista@jadlog.com.br; leon4rdoalves@gmail.com'
email.Subject = 'Relatório Mensal - Contas Processadas - Janeiro/26.'
email.Body = corpo_email

email.attachments.Add(
    r"C:\Users\monique.batista\OneDrive - JADLOG LOGISTICA LTDA\Área de Trabalho\Hashtag\Aula 04\base\contas_processadas.xlsx"
)

email.Send()

print('E-mail enviado com sucesso!')
# Out:
# E-mail enviado com sucesso!

# %% [markdown]
# Alerta Whatsapp

# %%
telefone = '+5511977629825'
mensagem = 'Relatório enviado no e-mail!'

kit.sendwhatmsg_instantly(
    telefone,
    mensagem,
    wait_time=10, #ATÉ 20seg
    tab_close=False
)

sleep(2)

pyautogui.press('enter')
print("Mensagem Wpp enviada com sucesso!")
# Out:
# Mensagem Wpp enviada com sucesso!

# %% [markdown]
# Criando executável

# %%
# !pip install pyinstaller

#!jupyter nbconvert --to script projeto.ipynb

# !pyinstaller --onefile projeto.py
# Out:
# 160 INFO: PyInstaller: 6.18.0, contrib hooks: 2026.0
# 160 INFO: Python: 3.10.4
# 251 INFO: Platform: Windows-10-10.0.26200-SP0
# 251 INFO: Python environment: C:\Program Files\Python310
# 255 INFO: wrote c:\Users\monique.batista\OneDrive - JADLOG LOGISTICA LTDA\Área de Trabalho\Hashtag\Aula 04\projeto.spec
# 277 INFO: Module search paths (PYTHONPATH):
# ['c:\\Users\\monique.batista\\AppData\\Roaming\\Python\\Python310\\Scripts\\pyinstaller.exe',
#  'C:\\Program Files\\Python310\\python310.zip',
#  'C:\\Program Files\\Python310\\DLLs',
#  'C:\\Program Files\\Python310\\lib',
#  'C:\\Program Files\\Python310',
#  'C:\\Users\\monique.batista\\AppData\\Roaming\\Python\\Python310\\site-packages',
#  'C:\\Users\\monique.batista\\AppData\\Roaming\\Python\\Python310\\site-packages\\win32',
#  'C:\\Users\\monique.batista\\AppData\\Roaming\\Python\\Python310\\site-packages\\win32\\lib',
#  'C:\\Users\\monique.batista\\AppData\\Roaming\\Python\\Python310\\site-packages\\Pythonwin',
#  'C:\\Program Files\\Python310\\lib\\site-packages',
#  'c:\\Users\\monique.batista\\OneDrive - JADLOG LOGISTICA LTDA\\Área de '
#  'Trabalho\\Hashtag\\Aula 04']
# 1760 INFO: checking Analysis
# 1761 INFO: Building Analysis because Analysis-00.toc is non existent
# 1761 INFO: Looking for Python shared library...
# 1762 INFO: Using Python shared library: C:\Program Files\Python310\python310.dll
# 1762 INFO: Running Analysis Analysis-00.toc
# 1762 INFO: Target bytecode optimization level: 0
# 1762 INFO: Initializing module dependency graph...
# 1768 INFO: Initializing module graph hook caches...
# 1831 INFO: Analyzing modules for base_library.zip ...
# 3392 INFO: Processing standard module hook 'hook-heapq.py' from 'C:\\Users\\monique.batista\\AppData\\Roaming\\Python\\Python310\\site-packages\\PyInstaller\\hooks'
# 3487 INFO: Processing standard module hook 'hook-encodings.py' from 'C:\\Users\\monique.batista\\AppData\\Roaming\\Python\\Python310\\site-packages\\PyInstaller\\hooks'
# 6232 INFO: Processing standard module hook 'hook-pickle.py' from 'C:\\Users\\monique.batista\\AppData\\Roaming\\Python\\Python310\\site-packages\\PyInstaller\\hooks'
# 9397 INFO: Caching module dependency graph...
# 9476 INFO: Analyzing c:\Users\monique.batista\OneDrive - JADLOG LOGISTICA LTDA\Área de Trabalho\Hashtag\Aula 04\projeto.py
# 9615 INFO: Processing standard module hook 'hook-platform.py' from 'C:\\Users\\monique.batista\\AppData\\Roaming\\Python\\Python310\\site-packages\\PyInstaller\\hooks'
# 9656 INFO: Processing pre-find-module-path hook 'hook-tkinter.py' from 'C:\\Users\\monique.batista\\AppData\\Roaming\\Python\\Python310\\site-packages\\PyInstaller\\hooks\\pre_find_module_path'
# 9658 INFO: TclTkInfo: initializing cached Tcl/Tk info...
# 10774 INFO: Processing standard module hook 'hook-_tkinter.py' from 'C:\\Users\\monique.batista\\AppData\\Roaming\\Python\\Python310\\site-packages\\PyInstaller\\hooks'
# 10828 INFO: Processing standard module hook 'hook-_ctypes.py' from 'C:\\Users\\monique.batista\\AppData\\Roaming\\Python\\Python310\\site-packages\\PyInstaller\\hooks'
# 10885 INFO: Processing standard module hook 'hook-PIL.py' from 'C:\\Users\\monique.batista\\AppData\\Roaming\\Python\\Python310\\site-packages\\PyInstaller\\hooks'
# 11140 INFO: Processing standard module hook 'hook-PIL.Image.py' from 'C:\\Users\\monique.batista\\AppData\\Roaming\\Python\\Python310\\site-packages\\PyInstaller\\hooks'
# 12391 INFO: Processing standard module hook 'hook-numpy.py' from 'C:\\Users\\monique.batista\\AppData\\Roaming\\Python\\Python310\\site-packages\\PyInstaller\\hooks'
# 13895 INFO: Processing standard module hook 'hook-sysconfig.py' from 'C:\\Users\\monique.batista\\AppData\\Roaming\\Python\\Python310\\site-packages\\PyInstaller\\hooks'
# 15925 INFO: Processing standard module hook 'hook-difflib.py' from 'C:\\Users\\monique.batista\\AppData\\Roaming\\Python\\Python310\\site-packages\\PyInstaller\\hooks'
# 16562 INFO: Processing standard module hook 'hook-multiprocessing.util.py' from 'C:\\Users\\monique.batista\\AppData\\Roaming\\Python\\Python310\\site-packages\\PyInstaller\\hooks'
# 16733 INFO: Processing standard module hook 'hook-xml.py' from 'C:\\Users\\monique.batista\\AppData\\Roaming\\Python\\Python310\\site-packages\\PyInstaller\\hooks'
# 17803 INFO: Processing standard module hook 'hook-psutil.py' from 'C:\\Users\\monique.batista\\AppData\\Roaming\\Python\\Python310\\site-packages\\_pyinstaller_hooks_contrib\\stdhooks'
# 19385 INFO: Processing standard module hook 'hook-charset_normalizer.py' from 'C:\\Users\\monique.batista\\AppData\\Roaming\\Python\\Python310\\site-packages\\_pyinstaller_hooks_contrib\\stdhooks'
# 19482 INFO: Processing pre-safe-import-module hook 'hook-typing_extensions.py' from 'C:\\Users\\monique.batista\\AppData\\Roaming\\Python\\Python310\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 19483 INFO: SetuptoolsInfo: initializing cached setuptools info...
# 20628 INFO: Processing standard module hook 'hook-xml.etree.cElementTree.py' from 'C:\\Users\\monique.batista\\AppData\\Roaming\\Python\\Python310\\site-packages\\PyInstaller\\hooks'
# 20696 INFO: Processing standard module hook 'hook-xml.dom.domreg.py' from 'C:\\Users\\monique.batista\\AppData\\Roaming\\Python\\Python310\\site-packages\\PyInstaller\\hooks'
# 20830 INFO: Processing standard module hook 'hook-PIL.ImageFilter.py' from 'C:\\Users\\monique.batista\\AppData\\Roaming\\Python\\Python310\\site-packages\\PyInstaller\\hooks'
# 21381 INFO: Processing pre-safe-import-module hook 'hook-packaging.py' from 'C:\\Users\\monique.batista\\AppData\\Roaming\\Python\\Python310\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 21543 INFO: Processing standard module hook 'hook-urllib3.py' from 'C:\\Users\\monique.batista\\AppData\\Roaming\\Python\\Python310\\site-packages\\_pyinstaller_hooks_contrib\\stdhooks'
# 22099 INFO: Processing standard module hook 'hook-cryptography.py' from 'C:\\Users\\monique.batista\\AppData\\Roaming\\Python\\Python310\\site-packages\\_pyinstaller_hooks_contrib\\stdhooks'
# 23925 INFO: hook-cryptography: cryptography does not seem to be using dynamically linked OpenSSL.
# 24207 INFO: Processing standard module hook 'hook-certifi.py' from 'C:\\Users\\monique.batista\\AppData\\Roaming\\Python\\Python310\\site-packages\\_pyinstaller_hooks_contrib\\stdhooks'
# 26215 INFO: Processing pre-safe-import-module hook 'hook-importlib_metadata.py' from 'C:\\Users\\monique.batista\\AppData\\Roaming\\Python\\Python310\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 26242 INFO: Processing standard module hook 'hook-importlib_metadata.py' from 'C:\\Users\\monique.batista\\AppData\\Roaming\\Python\\Python310\\site-packages\\PyInstaller\\hooks'
# 26282 INFO: Processing pre-safe-import-module hook 'hook-zipp.py' from 'C:\\Users\\monique.batista\\AppData\\Roaming\\Python\\Python310\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 26407 INFO: Processing standard module hook 'hook-jinja2.py' from 'C:\\Users\\monique.batista\\AppData\\Roaming\\Python\\Python310\\site-packages\\_pyinstaller_hooks_contrib\\stdhooks'
# 27037 INFO: Processing pre-safe-import-module hook 'hook-win32com.py' from 'C:\\Users\\monique.batista\\AppData\\Roaming\\Python\\Python310\\site-packages\\_pyinstaller_hooks_contrib\\pre_safe_import_module'
# 27192 INFO: Processing standard module hook 'hook-win32com.py' from 'C:\\Users\\monique.batista\\AppData\\Roaming\\Python\\Python310\\site-packages\\_pyinstaller_hooks_contrib\\stdhooks'
# 27194 INFO: Processing standard module hook 'hook-pythoncom.py' from 'C:\\Users\\monique.batista\\AppData\\Roaming\\Python\\Python310\\site-packages\\_pyinstaller_hooks_contrib\\stdhooks'
# 27440 INFO: Processing standard module hook 'hook-pywintypes.py' from 'C:\\Users\\monique.batista\\AppData\\Roaming\\Python\\Python310\\site-packages\\_pyinstaller_hooks_contrib\\stdhooks'
# 27940 INFO: Processing module hooks (post-graph stage)...
# 28592 INFO: Processing standard module hook 'hook-PIL.SpiderImagePlugin.py' from 'C:\\Users\\monique.batista\\AppData\\Roaming\\Python\\Python310\\site-packages\\PyInstaller\\hooks'
# 28618 INFO: Processing standard module hook 'hook-_tkinter.py' from 'C:\\Users\\monique.batista\\AppData\\Roaming\\Python\\Python310\\site-packages\\PyInstaller\\hooks'
# 28632 INFO: Performing binary vs. data reclassification (942 entries)
# 28965 INFO: Looking for ctypes DLLs
# 29010 INFO: Analyzing run-time hooks ...
# 29013 INFO: Including run-time hook 'pyi_rth_inspect.py' from 'C:\\Users\\monique.batista\\AppData\\Roaming\\Python\\Python310\\site-packages\\PyInstaller\\hooks\\rthooks'
# 29015 INFO: Including run-time hook 'pyi_rth_pywintypes.py' from 'C:\\Users\\monique.batista\\AppData\\Roaming\\Python\\Python310\\site-packages\\_pyinstaller_hooks_contrib\\rthooks'
# 29015 INFO: Including run-time hook 'pyi_rth_pythoncom.py' from 'C:\\Users\\monique.batista\\AppData\\Roaming\\Python\\Python310\\site-packages\\_pyinstaller_hooks_contrib\\rthooks'
# 29016 INFO: Including run-time hook 'pyi_rth_multiprocessing.py' from 'C:\\Users\\monique.batista\\AppData\\Roaming\\Python\\Python310\\site-packages\\PyInstaller\\hooks\\rthooks'
# 29017 INFO: Including run-time hook 'pyi_rth_cryptography_openssl.py' from 'C:\\Users\\monique.batista\\AppData\\Roaming\\Python\\Python310\\site-packages\\_pyinstaller_hooks_contrib\\rthooks'
# 29017 INFO: Including run-time hook 'pyi_rth_pkgutil.py' from 'C:\\Users\\monique.batista\\AppData\\Roaming\\Python\\Python310\\site-packages\\PyInstaller\\hooks\\rthooks'
# 29019 INFO: Including run-time hook 'pyi_rth__tkinter.py' from 'C:\\Users\\monique.batista\\AppData\\Roaming\\Python\\Python310\\site-packages\\PyInstaller\\hooks\\rthooks'
# 29051 INFO: Creating base_library.zip...
# 29095 INFO: Looking for dynamic libraries
# 30715 INFO: Extra DLL search directories (AddDllDirectory): ['C:\\Users\\monique.batista\\AppData\\Roaming\\Python\\Python310\\site-packages\\numpy.libs']
# 30715 INFO: Extra DLL search directories (PATH): []
# 32346 INFO: Warnings written to c:\Users\monique.batista\OneDrive - JADLOG LOGISTICA LTDA\Área de Trabalho\Hashtag\Aula 04\build\projeto\warn-projeto.txt
# 32482 INFO: Graph cross-reference written to c:\Users\monique.batista\OneDrive - JADLOG LOGISTICA LTDA\Área de Trabalho\Hashtag\Aula 04\build\projeto\xref-projeto.html
# 32616 INFO: checking PYZ
# 32616 INFO: Building PYZ because PYZ-00.toc is non existent
# 32616 INFO: Building PYZ (ZlibArchive) c:\Users\monique.batista\OneDrive - JADLOG LOGISTICA LTDA\Área de Trabalho\Hashtag\Aula 04\build\projeto\PYZ-00.pyz
# 34035 INFO: Building PYZ (ZlibArchive) c:\Users\monique.batista\OneDrive - JADLOG LOGISTICA LTDA\Área de Trabalho\Hashtag\Aula 04\build\projeto\PYZ-00.pyz completed successfully.
# 34194 INFO: checking PKG
# 34194 INFO: Building PKG because PKG-00.toc is non existent
# 34194 INFO: Building PKG (CArchive) projeto.pkg
# 42734 INFO: Building PKG (CArchive) projeto.pkg completed successfully.
# 42749 INFO: Bootloader C:\Users\monique.batista\AppData\Roaming\Python\Python310\site-packages\PyInstaller\bootloader\Windows-64bit-intel\run.exe
# 42749 INFO: checking EXE
# 42749 INFO: Building EXE because EXE-00.toc is non existent
# 42749 INFO: Building EXE from EXE-00.toc
# 42749 INFO: Copying bootloader EXE to c:\Users\monique.batista\OneDrive - JADLOG LOGISTICA LTDA\Área de Trabalho\Hashtag\Aula 04\dist\projeto.exe
# 42767 INFO: Copying icon to EXE
# 42778 WARNING: Execution of 'CopyIcons' failed on attempt #1 / 20: error(5, 'EndUpdateResourceW', 'Acesso negado.'). Retrying in 0.05 second(s)...
# 42861 INFO: Copying 0 resources to EXE
# 42861 INFO: Embedding manifest in EXE
# 42891 INFO: Appending PKG archive to EXE
# 43034 INFO: Fixing EXE headers
# 44177 INFO: Building EXE from EXE-00.toc completed successfully.
# 44194 INFO: Build complete! The results are available in: c:\Users\monique.batista\OneDrive - JADLOG LOGISTICA LTDA\Área de Trabalho\Hashtag\Aula 04\dist
